# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'COMMAND_MODE': 'unix2003', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': '/opt/anaconda3/bin/conda', 'CONDA_PREFIX': '/opt/anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': '/opt/anaconda3/bin/python', 'CONDA_SHLVL': '1', 'HOME': '/Users/MayankGarg', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'HOMEBREW_PREFIX': '/opt/homebrew', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'INFOPATH': '/opt/homebrew/share/info:', 'LOGNAME': 'MayankGarg', 'LaunchInstanceID': 'AF925ECD-191E-4443-A658-A3E099B08300', 'MANPATH': '/opt/homebrew/share/man::', 'MallocNanoZone': '0', 'MallocSpaceEfficient': '1', 'OLDPWD': '/Users/MayankGarg', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'PATH': '/opt/anaconda3/bin:/usr/bin:/bin:/usr/sbin:/sbin', 'PWD': '/', 'SHELL': '/bin/zsh', 'SHLVL': '2', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.bJMpogMLIA/Listeners', 'TMPDIR': '/var/folders/w4/lbqrw9sd4j58jmmm2ls54fxm0000gn/T/', 'USER': 'MayankGarg', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': '/Users/MayankGarg/Library/Application Support/Code/CachedData/6c3e3dba23e8fadc360aed75ce363ba185c49794', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': '/', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '/Users/MayankGarg/Library/Application Support/Code/1.81-main.sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-gb","osLocale":"en-in","availableLanguages":{},"_languagePackSupport":true}', 'VSCODE_PID': '22186', 'XPC_FLAGS': '0x0', 'XPC_SERVICE_NAME': '0', '_': '/opt/anaconda3/bin/python', '__CFBundleIdentifier': 'com.microsoft.VSCode', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'ELECTRON_RUN_AS_NODE': '1', 'WALLABY_PRODUCTION': 'true', 'VSCODE_L10N_BUNDLE_LOCATION': '', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'utf-8', '_CE_CONDA': '', 'CONDA_ROOT': '/opt/anaconda3', '_CE_M': '', 'LC_CTYPE': 'UTF-8', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}))

# %%
# #Fetching data form HERE API for IIT Bombay
# url = 'https://discover.search.hereapi.com/v1/discover?in=circle:28.6100216,77.0379647;r=100000&q=appartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
# # market,park
# data = requests.get(url).json()
# d=json_normalize(data['items'])
# # d.to_csv('api-data/apartment.csv')
# d

# %%
latitude=28.6100216
longitude=77.0379647
radius=100000


#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q=appartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude,longitude,radius)
# market,park
data = requests.get(url).json()
d=json_normalize(data['items'])
# d.to_csv('api-data/apartment.csv')
d
# Out:
#                                  title  \
# 0                    Shivam Properties
# 1       Kohinoor Guest House-Vikaspuri
# 2           Stay Royal Bed N Breakfast
# 3                             Green PG
# 4                     Vasant Apartment
# 5       Block E Vasant Vihar-Gate No 1
# 6   Air India Housing Colony-Gate No 1
# 7                    Rbi Officer Flats
# 8              Anand Niketan-Gate No 5
# 9              Anand Niketan-Gate No 6
# 10       CPWD Block G Type 3-Main Gate
# 11      Block B Vasant Vihar-Gate No 2
# 12  Air India Housing Colony-Gate No 2
# 13                 Deer Park Home Stay
# 14           Shanti Niketan Gate No 11
# 15        Central Govt Employees Flats
# 16        Apartment Rental-Flat Rental
# 17                Narmada Apartment N1
# 18                Narmada Apartment N3
# 19                Narmada Apartment N9
#
#                                                    id language  \
# 0   here:pds:place:356ttnfc-f19339dce0f13b2bdf4a0d...    en-GB
# 1   here:pds:place:356ttnfc-13a79363883a41eb9a57d7...       en
# 2   here:pds:place:356aabd1-9c7b9cf86e6409c61d67b8...       en
# 3   here:pds:place:356ttnf1-e3c810412f09412490e050...       en
# 4   here:pds:place:356jx7ps-8e58493aea0d0c1e17bc2e...    en-GB
# 5   here:pds:place:356jx7ps-94e722864b3902cee70ab4...    en-GB
# 6   here:pds:place:356jx7ps-39db02c85e5b0d7ce240a1...    en-GB
# 7   here:pds:place:356ttnf7-fe34bf8822054c89b7c6cf...    en-GB
# 8   here:pds:place:356jx7ps-7b8ceaf69f7e044f40bf7c...    en-GB
# 9   here:pds:place:356jx7ps-0816631bcf2b02210a74a3...    en-GB
# 10  here:pds:place:356jx7ps-d0af45f835440a017059c3...    en-GB
# 11  here:pds:place:356jx7ps-c82e3b6e19f50c4339e604...    en-GB
# 12  here:pds:place:356jx7ps-20b341352ae1065bb224f2...    en-GB
# 13  here:pds:place:356ttnfe-576fb955c0a04b209b68b2...       en
# 14  here:pds:place:356jx7ps-81af2558080c05a4db0fbd...    en-GB
# 15  here:pds:place:356ttnfs-b19aba517a564fd4ab179a...    en-GB
# 16  here:pds:place:356ttnfs-d49a03482b3f13a95c4bf8...       en
# 17  here:pds:place:356ttnf7-e1d0d0f792874f12afe304...    en-GB
# 18  here:pds:place:356ttnf7-de620715b74c490ba9ad43...    en-GB
# 19  here:pds:place:356ttnf7-de025e59b9f24623a64c94...    en-GB
#
#                                        ontologyId resultType  \
# 0   here:cm:ontology:apartment_rental_flat_rental      place
# 1   here:cm:ontology:apartment_rental_flat_rental      place
# 2   here:cm:ontology:apartment_rental_flat_rental      place
# 3   here:cm:ontology:apartment_rental_flat_rental      place
# 4   here:cm:ontology:apartment_rental_flat_rental      place
# 5   here:cm:ontology:apartment_rental_flat_rental      place
# 6   here:cm:ontology:apartment_rental_flat_rental      place
# 7   here:cm:ontology:apartment_rental_flat_rental      place
# 8   here:cm:ontology:apartment_rental_flat_rental      place
# 9   here:cm:ontology:apartment_rental_flat_rental      place
# 10  here:cm:ontology:apartment_rental_flat_rental      place
# 11  here:cm:ontology:apartment_rental_flat_rental      place
# 12  here:cm:ontology:apartment_rental_flat_rental      place
# 13  here:cm:ontology:apartment_rental_flat_rental      place
# 14  here:cm:ontology:apartment_rental_flat_rental      place
# 15  here:cm:ontology:apartment_rental_flat_rental      place
# 16  here:cm:ontology:apartment_rental_flat_rental      place
# 17  here:cm:ontology:apartment_rental_flat_rental      place
# 18  here:cm:ontology:apartment_rental_flat_rental      place
# 19  here:cm:ontology:apartment_rental_flat_rental      place
#
#                                   access  distance  \
# 0   [{'lat': 28.62028, 'lng': 77.04483}]      1332
# 1   [{'lat': 28.63858, 'lng': 77.07318}]      4675
# 2   [{'lat': 28.62105, 'lng': 77.10485}]      6641
# 3     [{'lat': 28.5102, 'lng': 77.0507}]     11174
# 4   [{'lat': 28.57407, 'lng': 77.15647}]     12243
# 5    [{'lat': 28.5645, 'lng': 77.15587}]     12562
# 6   [{'lat': 28.55917, 'lng': 77.15331}]     12605
# 7   [{'lat': 28.55971, 'lng': 77.15403}]     12636
# 8   [{'lat': 28.58152, 'lng': 77.16382}]     12696
# 9   [{'lat': 28.58059, 'lng': 77.16359}]     12701
# 10  [{'lat': 28.58128, 'lng': 77.16542}]     12848
# 11  [{'lat': 28.56803, 'lng': 77.16049}]     12848
# 12  [{'lat': 28.55808, 'lng': 77.15719}]     13003
# 13  [{'lat': 28.56611, 'lng': 77.16174}]     13026
# 14  [{'lat': 28.57852, 'lng': 77.17244}]     13607
# 15  [{'lat': 28.57847, 'lng': 77.17276}]     13618
# 16  [{'lat': 28.57374, 'lng': 77.17207}]     13700
# 17  [{'lat': 28.52545, 'lng': 77.14407}]     13986
# 18  [{'lat': 28.52548, 'lng': 77.14396}]     13991
# 19  [{'lat': 28.52543, 'lng': 77.14418}]     13997
#
#                                            categories  \
# 0   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 1   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 2   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 3   [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 4   [{'id': '900-9300-0221', 'name': 'Residential ...
# 5   [{'id': '900-9300-0221', 'name': 'Residential ...
# 6   [{'id': '900-9300-0221', 'name': 'Residential ...
# 7   [{'id': '900-9300-0221', 'name': 'Residential ...
# 8   [{'id': '900-9300-0221', 'name': 'Residential ...
# 9   [{'id': '900-9300-0221', 'name': 'Residential ...
# 10  [{'id': '900-9300-0221', 'name': 'Residential ...
# 11  [{'id': '900-9300-0221', 'name': 'Residential ...
# 12  [{'id': '900-9300-0221', 'name': 'Residential ...
# 13  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 14  [{'id': '900-9300-0221', 'name': 'Residential ...
# 15  [{'id': '900-9300-0221', 'name': 'Residential ...
# 16  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 17  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 18  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 19  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
#
#                                         address.label address.countryCode  \
# 0   Shivam Properties, Najafgarh Road, Nawada Extn...                 IND
# 1   Kohinoor Guest House-Vikaspuri, Guru Virjanand...                 IND
# 2   Stay Royal Bed N Breakfast, Jail Road, Maya En...                 IND
# 3   Green PG, Market Road, Sector 23, Gurugram 122...                 IND
# 4   Vasant Apartment, Vasant Village, Vasant Vihar...                 IND
# 5   Block E Vasant Vihar-Gate No 1, Paschimi Marg,...                 IND
# 6   Air India Housing Colony-Gate No 1, Poorvi Mar...                 IND
# 7   Rbi Officer Flats, Poorvi Marg, Block D, Vasan...                 IND
# 8   Anand Niketan-Gate No 5, Anand Niketan-Block D...                 IND
# 9   Anand Niketan-Gate No 6, Anand Niketan-Block D...                 IND
# 10  CPWD Block G Type 3-Main Gate, Shanti Niketan ...                 IND
# 11  Block B Vasant Vihar-Gate No 2, Paschimi Marg,...                 IND
# 12  Air India Housing Colony-Gate No 2, Air India ...                 IND
# 13  Deer Park Home Stay, B 7th Street, Block B, Va...                 IND
# 14  Shanti Niketan Gate No 11, Shanti Niketan Stre...                 IND
# 15  Central Govt Employees Flats, Moti Bagh South-...                 IND
# 16  Apartment Rental-Flat Rental, Sector 9, Ramakr...                 IND
# 17  Narmada Apartment N1, Sector D-Pocket 7, Vasan...                 IND
# 18  Narmada Apartment N3, Sector D-Pocket 7, Vasan...                 IND
# 19  Narmada Apartment N9, Sector D-Pocket 7, Vasan...                 IND
#
#     ... address.county address.city   address.district  \
# 0   ...           West        Delhi        Uttam Nagar
# 1   ...           West        Delhi         Vikas Puri
# 2   ...     South West        Delhi           Mayapuri
# 3   ...       Gurugram     Gurugram          Sector 23
# 4   ...     South West        Delhi       Vasant Vihar
# 5   ...     South West        Delhi       Vasant Vihar
# 6   ...     South West        Delhi       Vasant Vihar
# 7   ...     South West        Delhi       Vasant Vihar
# 8   ...     South West        Delhi          Moti Bagh
# 9   ...     South West        Delhi          Moti Bagh
# 10  ...     South West        Delhi          Moti Bagh
# 11  ...     South West        Delhi       Vasant Vihar
# 12  ...     South West        Delhi       Vasant Vihar
# 13  ...     South West        Delhi       Vasant Vihar
# 14  ...     South West        Delhi          Moti Bagh
# 15  ...     South West        Delhi          Moti Bagh
# 16  ...     South West        Delhi  Ramakrishna Puram
# 17  ...     South West        Delhi        Vasant Kunj
# 18  ...     South West        Delhi        Vasant Kunj
# 19  ...     South West        Delhi        Vasant Kunj
#
#          address.subdistrict         address.street address.postalCode  \
# 0                Nawada Extn         Najafgarh Road             110059
# 1                    Block C    Guru Virjanand Marg             110018
# 2               Maya Enclave              Jail Road             110064
# 3                        NaN            Market Road             122017
# 4             Vasant Village                    NaN             110057
# 5                    Block D          Paschimi Marg             110057
# 6   Air India Housing Colony            Poorvi Marg             110057
# 7                    Block D            Poorvi Marg             110057
# 8      Anand Niketan-Block D                    NaN             110021
# 9      Anand Niketan-Block D                    NaN             110021
# 10     Anand Niketan-Block B  Shanti Niketan Street             110021
# 11                   Block B          Paschimi Marg             110057
# 12  Air India Housing Colony                    NaN             110057
# 13                   Block B           B 7th Street             110057
# 14            Shanti Niketan  Shanti Niketan Street             110021
# 15   Moti Bagh South-Block C                    NaN             110021
# 16                  Sector 9                    NaN             110022
# 17         Sector D-Pocket 7                    NaN             110070
# 18         Sector D-Pocket 7                    NaN             110070
# 19         Sector D-Pocket 7                    NaN             110070
#
#    position.lat position.lng  \
# 0      28.62039     77.04480
# 1      28.63851     77.07318
# 2      28.62092     77.10485
# 3      28.51015     77.05069
# 4      28.57410     77.15650
# 5      28.56455     77.15574
# 6      28.55915     77.15333
# 7      28.55974     77.15401
# 8      28.58164     77.16392
# 9      28.58061     77.16366
# 10     28.58130     77.16543
# 11     28.56797     77.16053
# 12     28.55816     77.15732
# 13     28.56604     77.16161
# 14     28.57840     77.17260
# 15     28.57849     77.17274
# 16     28.57372     77.17205
# 17     28.52558     77.14411
# 18     28.52537     77.14396
# 19     28.52555     77.14422
#
#                                              contacts  \
# 0                                                 NaN
# 1                                                 NaN
# 2           [{'phone': [{'value': '+919212243611'}]}]
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [{'phone': [{'value': '+919650936501'}], 'www'...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                            references
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'supplier': {'id': 'core'}, 'id': '104832572...
# 5   [{'supplier': {'id': 'core'}, 'id': '112265777...
# 6   [{'supplier': {'id': 'core'}, 'id': '104832580...
# 7   [{'supplier': {'id': 'core'}, 'id': '120777422...
# 8   [{'supplier': {'id': 'core'}, 'id': '110391543...
# 9   [{'supplier': {'id': 'core'}, 'id': '110391871...
# 10  [{'supplier': {'id': 'core'}, 'id': '113510945...
# 11  [{'supplier': {'id': 'core'}, 'id': '116404307...
# 12  [{'supplier': {'id': 'core'}, 'id': '104832576...
# 13                                                NaN
# 14  [{'supplier': {'id': 'core'}, 'id': '110394068...
# 15  [{'supplier': {'id': 'core'}, 'id': '107055346...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 23 columns]

# %%
# #Fetching data form HERE API for IIT Bombay
# url = 'https://discover.search.hereapi.com/v1/discover?in=circle:28.6100216,77.0379647;r=10000&q=pg&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
# # market,park,high school,hospital,mall
# data = requests.get(url).json()
# d=json_normalize(data['items'])
# d.to_csv('api-data/apartment.csv')
# d

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','contacts','id']]
# d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                                  title  \
# 0                    Shivam Properties
# 1       Kohinoor Guest House-Vikaspuri
# 2           Stay Royal Bed N Breakfast
# 3                             Green PG
# 4                     Vasant Apartment
# 5       Block E Vasant Vihar-Gate No 1
# 6   Air India Housing Colony-Gate No 1
# 7                    Rbi Officer Flats
# 8              Anand Niketan-Gate No 5
# 9              Anand Niketan-Gate No 6
# 10       CPWD Block G Type 3-Main Gate
# 11      Block B Vasant Vihar-Gate No 2
# 12  Air India Housing Colony-Gate No 2
# 13                 Deer Park Home Stay
# 14           Shanti Niketan Gate No 11
# 15        Central Govt Employees Flats
# 16        Apartment Rental-Flat Rental
# 17                Narmada Apartment N1
# 18                Narmada Apartment N3
# 19                Narmada Apartment N9
#
#                                         address.label  distance  \
# 0   Shivam Properties, Najafgarh Road, Nawada Extn...      1332
# 1   Kohinoor Guest House-Vikaspuri, Guru Virjanand...      4675
# 2   Stay Royal Bed N Breakfast, Jail Road, Maya En...      6641
# 3   Green PG, Market Road, Sector 23, Gurugram 122...     11174
# 4   Vasant Apartment, Vasant Village, Vasant Vihar...     12243
# 5   Block E Vasant Vihar-Gate No 1, Paschimi Marg,...     12562
# 6   Air India Housing Colony-Gate No 1, Poorvi Mar...     12605
# 7   Rbi Officer Flats, Poorvi Marg, Block D, Vasan...     12636
# 8   Anand Niketan-Gate No 5, Anand Niketan-Block D...     12696
# 9   Anand Niketan-Gate No 6, Anand Niketan-Block D...     12701
# 10  CPWD Block G Type 3-Main Gate, Shanti Niketan ...     12848
# 11  Block B Vasant Vihar-Gate No 2, Paschimi Marg,...     12848
# 12  Air India Housing Colony-Gate No 2, Air India ...     13003
# 13  Deer Park Home Stay, B 7th Street, Block B, Va...     13026
# 14  Shanti Niketan Gate No 11, Shanti Niketan Stre...     13607
# 15  Central Govt Employees Flats, Moti Bagh South-...     13618
# 16  Apartment Rental-Flat Rental, Sector 9, Ramakr...     13700
# 17  Narmada Apartment N1, Sector D-Pocket 7, Vasan...     13986
# 18  Narmada Apartment N3, Sector D-Pocket 7, Vasan...     13991
# 19  Narmada Apartment N9, Sector D-Pocket 7, Vasan...     13997
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 28.62028, 'lng': 77.04483}]      28.62039      77.04480
# 1   [{'lat': 28.63858, 'lng': 77.07318}]      28.63851      77.07318
# 2   [{'lat': 28.62105, 'lng': 77.10485}]      28.62092      77.10485
# 3     [{'lat': 28.5102, 'lng': 77.0507}]      28.51015      77.05069
# 4   [{'lat': 28.57407, 'lng': 77.15647}]      28.57410      77.15650
# 5    [{'lat': 28.5645, 'lng': 77.15587}]      28.56455      77.15574
# 6   [{'lat': 28.55917, 'lng': 77.15331}]      28.55915      77.15333
# 7   [{'lat': 28.55971, 'lng': 77.15403}]      28.55974      77.15401
# 8   [{'lat': 28.58152, 'lng': 77.16382}]      28.58164      77.16392
# 9   [{'lat': 28.58059, 'lng': 77.16359}]      28.58061      77.16366
# 10  [{'lat': 28.58128, 'lng': 77.16542}]      28.58130      77.16543
# 11  [{'lat': 28.56803, 'lng': 77.16049}]      28.56797      77.16053
# 12  [{'lat': 28.55808, 'lng': 77.15719}]      28.55816      77.15732
# 13  [{'lat': 28.56611, 'lng': 77.16174}]      28.56604      77.16161
# 14  [{'lat': 28.57852, 'lng': 77.17244}]      28.57840      77.17260
# 15  [{'lat': 28.57847, 'lng': 77.17276}]      28.57849      77.17274
# 16  [{'lat': 28.57374, 'lng': 77.17207}]      28.57372      77.17205
# 17  [{'lat': 28.52545, 'lng': 77.14407}]      28.52558      77.14411
# 18  [{'lat': 28.52548, 'lng': 77.14396}]      28.52537      77.14396
# 19  [{'lat': 28.52543, 'lng': 77.14418}]      28.52555      77.14422
#
#    address.postalCode                                           contacts  \
# 0              110059                                                NaN
# 1              110018                                                NaN
# 2              110064          [{'phone': [{'value': '+919212243611'}]}]
# 3              122017                                                NaN
# 4              110057                                                NaN
# 5              110057                                                NaN
# 6              110057                                                NaN
# 7              110057                                                NaN
# 8              110021                                                NaN
# 9              110021                                                NaN
# 10             110021                                                NaN
# 11             110057                                                NaN
# 12             110057                                                NaN
# 13             110057  [{'phone': [{'value': '+919650936501'}], 'www'...
# 14             110021                                                NaN
# 15             110021                                                NaN
# 16             110022                                                NaN
# 17             110070                                                NaN
# 18             110070                                                NaN
# 19             110070                                                NaN
#
#                                                    id
# 0   here:pds:place:356ttnfc-f19339dce0f13b2bdf4a0d...
# 1   here:pds:place:356ttnfc-13a79363883a41eb9a57d7...
# 2   here:pds:place:356aabd1-9c7b9cf86e6409c61d67b8...
# 3   here:pds:place:356ttnf1-e3c810412f09412490e050...
# 4   here:pds:place:356jx7ps-8e58493aea0d0c1e17bc2e...
# 5   here:pds:place:356jx7ps-94e722864b3902cee70ab4...
# 6   here:pds:place:356jx7ps-39db02c85e5b0d7ce240a1...
# 7   here:pds:place:356ttnf7-fe34bf8822054c89b7c6cf...
# 8   here:pds:place:356jx7ps-7b8ceaf69f7e044f40bf7c...
# 9   here:pds:place:356jx7ps-0816631bcf2b02210a74a3...
# 10  here:pds:place:356jx7ps-d0af45f835440a017059c3...
# 11  here:pds:place:356jx7ps-c82e3b6e19f50c4339e604...
# 12  here:pds:place:356jx7ps-20b341352ae1065bb224f2...
# 13  here:pds:place:356ttnfe-576fb955c0a04b209b68b2...
# 14  here:pds:place:356jx7ps-81af2558080c05a4db0fbd...
# 15  here:pds:place:356ttnfs-b19aba517a564fd4ab179a...
# 16  here:pds:place:356ttnfs-d49a03482b3f13a95c4bf8...
# 17  here:pds:place:356ttnf7-e1d0d0f792874f12afe304...
# 18  here:pds:place:356ttnf7-de620715b74c490ba9ad43...
# 19  here:pds:place:356ttnf7-de025e59b9f24623a64c94...

# %%
#Counting no. of cafes, department stores and gyms near apartments around IIT Bombay
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '1000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    CafeList.append(venues['title'].count())
	
    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    GymList.append(venues['title'].count())

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    ResList.append(venues['title'].count())

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList

df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms
# 0       28.62039      77.04480      1           20    20
# 1       28.63851      77.07318     12           20    20
# 2       28.62092      77.10485      4           20    17
# 3       28.51015      77.05069      8           20    17
# 4       28.57410      77.15650      1           20     3
# 5       28.56455      77.15574      3           20     7
# 6       28.55915      77.15333      3           20     4
# 7       28.55974      77.15401      5           20     8
# 8       28.58164      77.16392     18           20     8
# 9       28.58061      77.16366     15           20     7
# 10      28.58130      77.16543     19           20     8
# 11      28.56797      77.16053      4           20    12
# 12      28.55816      77.15732     14           20    10
# 13      28.56604      77.16161     12           20    15
# 14      28.57840      77.17260      8           20     3
# 15      28.57849      77.17274      8           20     3
# 16      28.57372      77.17205      7           20     3
# 17      28.52558      77.14411      7           20    11
# 18      28.52537      77.14396      7           20    11
# 19      28.52555      77.14422      7           20    11

# %%
#Run K-means clustering on dataframe
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       28.62039      77.04480      1           20    20       2
# 1       28.63851      77.07318     12           20    20       2
# 2       28.62092      77.10485      4           20    17       2
# 3       28.51015      77.05069      8           20    17       2
# 4       28.57410      77.15650      1           20     3       1
# 5       28.56455      77.15574      3           20     7       1
# 6       28.55915      77.15333      3           20     4       1
# 7       28.55974      77.15401      5           20     8       1
# 8       28.58164      77.16392     18           20     8       0
# 9       28.58061      77.16366     15           20     7       0
# 10      28.58130      77.16543     19           20     8       0
# 11      28.56797      77.16053      4           20    12       2
# 12      28.55816      77.15732     14           20    10       0
# 13      28.56604      77.16161     12           20    15       2
# 14      28.57840      77.17260      8           20     3       1
# 15      28.57849      77.17274      8           20     3       1
# 16      28.57372      77.17205      7           20     3       1
# 17      28.52558      77.14411      7           20    11       2
# 18      28.52537      77.14396      7           20    11       2
# 19      28.52555      77.14422      7           20    11       2

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[28.6100216,77.0379647],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([28.6100216,77.0379647],popup='NSUT').add_to(map_bom)

# %%
#saving the map 
# map_bom.save("map-ok.html")

# %%
df_final.columns
# Out:
# Index(['position.lat', 'position.lng', 'Cafes', 'Restaurents', 'Gyms',
#        'Cluster'],
#       dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   position.lat  20 non-null     float64
#  1   position.lng  20 non-null     float64
#  2   Cafes         20 non-null     int64
#  3   Restaurents   20 non-null     int64
#  4   Gyms          20 non-null     int64
#  5   Cluster       20 non-null     object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.1+ KB

# %%
df_final[df_final['Cluster']=='1']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 4       28.57410      77.15650      1           20     3       1
# 5       28.56455      77.15574      3           20     7       1
# 6       28.55915      77.15333      3           20     4       1
# 7       28.55974      77.15401      5           20     8       1
# 14      28.57840      77.17260      8           20     3       1
# 15      28.57849      77.17274      8           20     3       1
# 16      28.57372      77.17205      7           20     3       1

# %%
df_final[df_final['Cluster']=='0']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 8       28.58164      77.16392     18           20     8       0
# 9       28.58061      77.16366     15           20     7       0
# 10      28.58130      77.16543     19           20     8       0
# 12      28.55816      77.15732     14           20    10       0

# %%
df_final[df_final['Cluster']=='2']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       28.62039      77.04480      1           20    20       2
# 1       28.63851      77.07318     12           20    20       2
# 2       28.62092      77.10485      4           20    17       2
# 3       28.51015      77.05069      8           20    17       2
# 11      28.56797      77.16053      4           20    12       2
# 13      28.56604      77.16161     12           20    15       2
# 17      28.52558      77.14411      7           20    11       2
# 18      28.52537      77.14396      7           20    11       2
# 19      28.52555      77.14422      7           20    11       2

# %%
map_bom
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06686bbae70ee4f27a0644d5e86c306a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06686bbae70ee4f27a0644d5e86c306a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06686bbae70ee4f27a0644d5e86c306a = L.map(
#                 &quot;map_06686bbae70ee4f27a0644d5e86c306a&quot;,
#                 {
#                     center: [28.6100216, 77.0379647],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f6754e67c5f9039c8df432c0568d3bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06686bbae70ee4f27a0644d5e86c306a);
#
#
#             var circle_marker_4f8e30a88d8f7a151c0dd4aab32e0316 = L.circleMarker(
#                 [28.62039, 77.0448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_06686bbae70ee4f27a0644d5e86c306a);
#
#
#         var popup_0897eace620a57442b135380ecc0d632 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a85fb7d6c32ada6a9f83d3467f4ee8b5 = $(`&lt;div id=&quot;html_a85fb7d6c32ada6a9f83d3467f4ee8b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shivam Properties&lt;/div&gt;`)[0];
#                 popup_0897eace620a57442b135380ecc0d632.setContent(html_a85fb7d6c32ada6a9f83d3467f4ee8b5);
#
#
#
#         circle_marker_4f8e30a88d8f7a151c0dd4aab32e0316.bindPopup(popup_0897eace620a57442b135380ecc0d632)
#         ;
#
#
#
#
#             var circle_marker_f6b4c6a767b3cbb559c9669825551a0a = L.circleMarker(
#                 [28.63851, 77.07318],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_06686bbae70ee4f27a0644d5e86c306a);
#
#
#         var popup_f80cd6064e11120fcce099e0a326f797 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_553ee5f83e5a38a75bd4284de2d9413e = $(`&lt;div id=&quot;html_553ee5f83e5a38a75bd4284de2d9413e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kohinoor Guest House-Vikaspuri&lt;/div&gt;`)[0];
#                 popup_f80cd6064e11120fcce099e0a326f797.setContent(html_553ee5f83e5a38a75bd4284de2d9413e);
#
#
#
#         circle_marker_f6b4c6a767b3cbb559c9669825551a0a.bindPopup(popup_f80cd6064e11120fcce099e0a326f797)
#         ;
#
#
#
#
#             var circle_marker_e36a88cf7fdfbed73c2c3bc1c4f19252 = L.circleMarker(
#                 [28.62092, 77.10485],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_06686bbae70ee4f27a0644d5e86c306a);
#
#
#         var popup_f88839fe4ed7f4b59e235c74bee8caf7 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_cd069c55343d5b72ec1011ac8276972b = $(`&lt;div id=&quot;html_cd069c55343d5b72ec1011ac8276972b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stay Royal Bed N Breakfast&lt;/div&gt;`)[0];
#                 popup_f88839fe4ed7f4b59e235c74bee8caf7.setContent(html_cd069c55343d5b72ec1011ac8276972b);
#
#
#
#         circle_marker_e36a88cf7fdfbed73c2c3bc1c4f19252.bindPopup(popup_f88839fe4ed7f4b59e235c74bee8caf7)
#         ;
#
#
#
#
#             var circle_marker_6c536923fdda07c362e4c64377f0b778 = L.circleMarker(
#                 [28.51015, 77.05069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &qu

# %%
map_string = map_bom.get_map_html()

# Create a new section in Streamlit


# Display the map object in the section
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w4/lbqrw9sd4j58jmmm2ls54fxm0000gn/T/ipykernel_29298/3847984126.py in <module>
# ----> 1 map_string = map_bom.get_map_html()
#       2
#       3 # Create a new section in Streamlit
#       4
#       5
#
# AttributeError: 'Map' object has no attribute 'get_map_html'
