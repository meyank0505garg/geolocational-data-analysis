# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'COMMAND_MODE': 'unix2003', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': '/opt/anaconda3/bin/conda', 'CONDA_PREFIX': '/opt/anaconda3', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': '/opt/anaconda3/bin/python', 'CONDA_SHLVL': '1', 'HOME': '/Users/MayankGarg', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'HOMEBREW_PREFIX': '/opt/homebrew', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'INFOPATH': '/opt/homebrew/share/info:', 'LOGNAME': 'MayankGarg', 'LaunchInstanceID': '2DBBEC27-A5D4-4532-9ADB-EE726A5690D8', 'MANPATH': '/opt/homebrew/share/man::', 'MallocNanoZone': '0', 'MallocSpaceEfficient': '1', 'OLDPWD': '/Users/MayankGarg', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'PATH': '/opt/anaconda3/bin:/usr/bin:/bin:/usr/sbin:/sbin', 'PWD': '/', 'SHELL': '/bin/zsh', 'SHLVL': '2', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.bJMpogMLIA/Listeners', 'TMPDIR': '/var/folders/w4/lbqrw9sd4j58jmmm2ls54fxm0000gn/T/', 'USER': 'MayankGarg', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': '/Users/MayankGarg/Library/Application Support/Code/CachedData/6c3e3dba23e8fadc360aed75ce363ba185c49794', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': '/', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '/Users/MayankGarg/Library/Application Support/Code/1.81-main.sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-gb","osLocale":"en-in","availableLanguages":{},"_languagePackSupport":true}', 'VSCODE_PID': '92186', 'XPC_FLAGS': '0x0', 'XPC_SERVICE_NAME': '0', '_': '/opt/anaconda3/bin/python', '__CFBundleIdentifier': 'com.microsoft.VSCode', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'ELECTRON_RUN_AS_NODE': '1', 'WALLABY_PRODUCTION': 'true', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'utf-8', '_CE_CONDA': '', 'CONDA_ROOT': '/opt/anaconda3', '_CE_M': '', 'LC_CTYPE': 'UTF-8', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}))

# %%
# #Fetching data form HERE API for IIT Bombay
# url = 'https://discover.search.hereapi.com/v1/discover?in=circle:28.6100216,77.0379647;r=100000&q=appartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
# # market,park
# data = requests.get(url).json()
# d=json_normalize(data['items'])
# # d.to_csv('api-data/apartment.csv')
# d

# %%
latitude=28.75005
longitude=77.1156389
radius=100000
thing='pg'
facilities_list_name=['gym','Restaurents','cafe']


#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{0},{1};r={2}&q={3}&apiKey=kW5ZzpawjBDJ0waMxzGx_a3cFfR9bgWK-5ejXI9xt1s'.format(
            latitude, longitude, radius,thing)
# market,park
data = requests.get(url).json()
d=json_normalize(data['items'])
# d.to_csv('api-data/apartment.csv')
d
# Out:
#        title                                                 id language  \
# 0  Sakshi PG  here:pds:place:356ttngd-9ad97e25f8f082b189e034...       en
#
#   resultType                                access  distance  \
# 0      place  [{'lat': 28.75046, 'lng': 77.11646}]        97
#
#                                           categories  \
# 0  [{'id': '500-5100-0000', 'name': 'Lodging', 'p...
#
#                             address.label address.countryCode  \
# 0  Sakshi PG, Rohini, Delhi 110042, India                 IND
#
#   address.countryName address.stateCode address.state address.county  \
# 0               India                DL         Delhi     North West
#
#   address.city address.district address.postalCode  position.lat  position.lng
# 0        Delhi           Rohini             110042      28.75055      77.11646

# %%
# #Fetching data form HERE API for IIT Bombay
# url = 'https://discover.search.hereapi.com/v1/discover?in=circle:28.6100216,77.0379647;r=10000&q=pg&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
# # market,park,high school,hospital,mall
# data = requests.get(url).json()
# d=json_normalize(data['items'])
# d.to_csv('api-data/apartment.csv')
# d
d.shape
# Out:
# (1, 18)

# %%
d2 = d[['title','position.lat', 'position.lng']]
d2
# Out:
#        title  position.lat  position.lng
# 0  Sakshi PG      28.75055      77.11646

# %%
#Cleaning API data

d2=d[['title','position.lat','position.lng']]
# d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#        title  position.lat  position.lng
# 0  Sakshi PG      28.75055      77.11646

# %%
def fill_facilitites(search_query,List,latitude,longitude):
    radius = '1000'
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(
        latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues = json_normalize(results['items'])
    List.append(venues['title'].count())

# %%
def fill_facilitites_copy(search_query,List,latitude,longitude,index):
    radius = '1000'
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(
        latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues = json_normalize(results['items'])
    List[index].append(venues['title'].count())

# %%
latitudes = list(d2['position.lat'])
longitudes = list(d2['position.lng'])

List = [[] for _ in range(len(facilities_list_name))]
for lat, lng in zip(latitudes, longitudes):
    latitude = lat
    longitude = lng


    for i in range(0,len(facilities_list_name)):
        fill_facilitites(facilities_list_name[i], List, latitude, longitude, i)


for i in range(0,len(List)):
        # st.sidebar.write(facilities_list_name[i] , " | ", len(List[i]) )
    df_final[facilities_list_name[i]]=List[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w4/lbqrw9sd4j58jmmm2ls54fxm0000gn/T/ipykernel_9028/725833634.py in <module>
#      15 for i in range(0,len(List)):
#      16         # st.sidebar.write(facilities_list_name[i] , " | ", len(List[i]) )
# ---> 17     df_final[facilities_list_name[i]]=List[i]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (1)

# %%
List
# Out:
# [[20, 20, 17, 17, 3, 7, 4, 8, 8, 7, 8, 12, 10, 15, 3, 3, 3, 11, 11, 11],
#  [1, 12, 4, 8, 1, 3, 3, 5, 18, 15, 19, 4, 14, 12, 8, 8, 7, 7, 7, 7],
#  [1, 12, 4, 8, 1, 3, 3, 5, 18, 15, 19, 4, 14, 12, 8, 8, 7, 7, 7, 7]]

# %%
#Run K-means clustering on dataframe
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       28.62039      77.04480      1           20    20       2
# 1       28.63851      77.07318     12           20    20       2
# 2       28.62092      77.10485      4           20    17       2
# 3       28.51015      77.05069      8           20    17       2
# 4       28.57410      77.15650      1           20     3       1
# 5       28.56455      77.15574      3           20     7       1
# 6       28.55915      77.15333      3           20     4       1
# 7       28.55974      77.15401      5           20     8       1
# 8       28.58164      77.16392     18           20     8       0
# 9       28.58061      77.16366     15           20     7       0
# 10      28.58130      77.16543     19           20     8       0
# 11      28.56797      77.16053      4           20    12       2
# 12      28.55816      77.15732     14           20    10       0
# 13      28.56604      77.16161     12           20    15       2
# 14      28.57840      77.17260      8           20     3       1
# 15      28.57849      77.17274      8           20     3       1
# 16      28.57372      77.17205      7           20     3       1
# 17      28.52558      77.14411      7           20    11       2
# 18      28.52537      77.14396      7           20    11       2
# 19      28.52555      77.14422      7           20    11       2

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[28.6100216,77.0379647],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([28.6100216,77.0379647],popup='NSUT').add_to(map_bom)

# %%
#saving the map 
# map_bom.save("map-ok.html")

# %%
df_final.columns
# Out:
# Index(['position.lat', 'position.lng', 'Cafes', 'Restaurents', 'Gyms',
#        'Cluster'],
#       dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   position.lat  20 non-null     float64
#  1   position.lng  20 non-null     float64
#  2   Cafes         20 non-null     int64
#  3   Restaurents   20 non-null     int64
#  4   Gyms          20 non-null     int64
#  5   Cluster       20 non-null     object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.1+ KB

# %%
df_final[df_final['Cluster']=='1']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 4       28.57410      77.15650      1           20     3       1
# 5       28.56455      77.15574      3           20     7       1
# 6       28.55915      77.15333      3           20     4       1
# 7       28.55974      77.15401      5           20     8       1
# 14      28.57840      77.17260      8           20     3       1
# 15      28.57849      77.17274      8           20     3       1
# 16      28.57372      77.17205      7           20     3       1

# %%
df_final[df_final['Cluster']=='0']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 8       28.58164      77.16392     18           20     8       0
# 9       28.58061      77.16366     15           20     7       0
# 10      28.58130      77.16543     19           20     8       0
# 12      28.55816      77.15732     14           20    10       0

# %%
df_final[df_final['Cluster']=='2']
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       28.62039      77.04480      1           20    20       2
# 1       28.63851      77.07318     12           20    20       2
# 2       28.62092      77.10485      4           20    17       2
# 3       28.51015      77.05069      8           20    17       2
# 11      28.56797      77.16053      4           20    12       2
# 13      28.56604      77.16161     12           20    15       2
# 17      28.52558      77.14411      7           20    11       2
# 18      28.52537      77.14396      7           20    11       2
# 19      28.52555      77.14422      7           20    11       2

# %%
map_bom
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8b9ccade23c442896edf48cd99fe095 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8b9ccade23c442896edf48cd99fe095&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8b9ccade23c442896edf48cd99fe095 = L.map(
#                 &quot;map_f8b9ccade23c442896edf48cd99fe095&quot;,
#                 {
#                     center: [28.6100216, 77.0379647],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fecba05e044e0cb92bff6ce738fd31e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f8b9ccade23c442896edf48cd99fe095);
#
#
#             var circle_marker_ebcc7e721e47daca11333c836d57a5ff = L.circleMarker(
#                 [28.62039, 77.0448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8b9ccade23c442896edf48cd99fe095);
#
#
#         var popup_fcd1343fc21585f5477b95da4975ebf1 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3ab7a6fb81e4df69f83e85489de9de7d = $(`&lt;div id=&quot;html_3ab7a6fb81e4df69f83e85489de9de7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shivam Properties&lt;/div&gt;`)[0];
#                 popup_fcd1343fc21585f5477b95da4975ebf1.setContent(html_3ab7a6fb81e4df69f83e85489de9de7d);
#
#
#
#         circle_marker_ebcc7e721e47daca11333c836d57a5ff.bindPopup(popup_fcd1343fc21585f5477b95da4975ebf1)
#         ;
#
#
#
#
#             var circle_marker_e0f20ff3839f17c4e7a6a934438aa6cd = L.circleMarker(
#                 [28.63851, 77.07318],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8b9ccade23c442896edf48cd99fe095);
#
#
#         var popup_5099b1749f1d63af4f2e8f41315436bf = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_8dbd6ed3939027bd5d70062f772ac293 = $(`&lt;div id=&quot;html_8dbd6ed3939027bd5d70062f772ac293&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kohinoor Guest House-Vikaspuri&lt;/div&gt;`)[0];
#                 popup_5099b1749f1d63af4f2e8f41315436bf.setContent(html_8dbd6ed3939027bd5d70062f772ac293);
#
#
#
#         circle_marker_e0f20ff3839f17c4e7a6a934438aa6cd.bindPopup(popup_5099b1749f1d63af4f2e8f41315436bf)
#         ;
#
#
#
#
#             var circle_marker_af71a88c217e25dca6bc64add75ba1b1 = L.circleMarker(
#                 [28.62092, 77.10485],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f8b9ccade23c442896edf48cd99fe095);
#
#
#         var popup_ee2547a77c872d4600c643ab38fea06b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3eb5853cd16f58059ae97f3834e28472 = $(`&lt;div id=&quot;html_3eb5853cd16f58059ae97f3834e28472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stay Royal Bed N Breakfast&lt;/div&gt;`)[0];
#                 popup_ee2547a77c872d4600c643ab38fea06b.setContent(html_3eb5853cd16f58059ae97f3834e28472);
#
#
#
#         circle_marker_af71a88c217e25dca6bc64add75ba1b1.bindPopup(popup_ee2547a77c872d4600c643ab38fea06b)
#         ;
#
#
#
#
#             var circle_marker_8610099e77df69b5a12c7eaee9a600cc = L.circleMarker(
#                 [28.51015, 77.05069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &qu

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w4/lbqrw9sd4j58jmmm2ls54fxm0000gn/T/ipykernel_54119/3847984126.py in <module>
# ----> 1 map_string = map_bom.get_map_html()
#       2
#       3 # Create a new section in Streamlit
#       4
#       5
#
# AttributeError: 'Map' object has no attribute 'get_map_html'

# %%
List=[]
list1=[[1,2,3]]
list2=[4,5,6]
list3=[7,8,9]
List.append(list1)
List.append(list2)
List.append(list3)

print(List[0])
# Out:
# [1, 2, 3]

# %%
counter=0;

for i in range(0,len(List)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
List=[[] for _ in range(3)]
List[0].append(1)
List[1].append(2)
print(List)
# Out:
# [[1], [2], []]

# %%
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms
# 0       28.62039      77.04480      1           20     1
# 1       28.63851      77.07318     12           20    12
# 2       28.62092      77.10485      4           20     4
# 3       28.51015      77.05069      8           20     8
# 4       28.57410      77.15650      1           20     1
# 5       28.56455      77.15574      3           20     3
# 6       28.55915      77.15333      3           20     3
# 7       28.55974      77.15401      5           20     5
# 8       28.58164      77.16392     18           20    18
# 9       28.58061      77.16366     15           20    15
# 10      28.58130      77.16543     19           20    19
# 11      28.56797      77.16053      4           20     4
# 12      28.55816      77.15732     14           20    14
# 13      28.56604      77.16161     12           20    12
# 14      28.57840      77.17260      8           20     8
# 15      28.57849      77.17274      8           20     8
# 16      28.57372      77.17205      7           20     7
# 17      28.52558      77.14411      7           20     7
# 18      28.52537      77.14396      7           20     7
# 19      28.52555      77.14422      7           20     7

# %%
name_df=pd.DataFrame()
name_df['name']=d2['title']

# %%
name_df
# Out:
#                                   name
# 0                    Shivam Properties
# 1       Kohinoor Guest House-Vikaspuri
# 2           Stay Royal Bed N Breakfast
# 3                             Green PG
# 4                     Vasant Apartment
# 5       Block E Vasant Vihar-Gate No 1
# 6   Air India Housing Colony-Gate No 1
# 7                    Rbi Officer Flats
# 8              Anand Niketan-Gate No 5
# 9              Anand Niketan-Gate No 6
# 10       CPWD Block G Type 3-Main Gate
# 11      Block B Vasant Vihar-Gate No 2
# 12  Air India Housing Colony-Gate No 2
# 13                 Deer Park Home Stay
# 14           Shanti Niketan Gate No 11
# 15        Central Govt Employees Flats
# 16        Apartment Rental-Flat Rental
# 17                Narmada Apartment N1
# 18                Narmada Apartment N3
# 19                Narmada Apartment N9

# %%
df_final.columns[2]
# Out:
# 'Cafes'
