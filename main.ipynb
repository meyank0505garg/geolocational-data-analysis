# %%
import numpy as np 
from tabulate import tabulate
import pandas as pd 
from sklearn.cluster import KMeans
import random
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
#data cleaning and extracting relevant features
df1 = pd.read_csv("Data/food_cleaned_data.csv")
df=df1[["cook","diet_current_coded","eating_out","sports","exercise","fav_cuisine_coded","on_off_campus","pay_meal_out","fav_food","fruit_day","income"]]
df.dropna(axis=0,inplace=True)
df.to_csv("Data/food_choices.csv")
df
# Out:
#      cook  diet_current_coded  eating_out  sports  exercise  \
# 0       2                   1           3       1         1
# 1       3                   2           2       1         1
# 2       1                   3           2       2         2
# 3       2                   2           2       2         3
# 4       1                   2           2       1         1
# ..    ...                 ...         ...     ...       ...
# 120     3                   2           2       1         2
# 121     3                   2           4       1         2
# 122     3                   2           3       2         2
# 123     3                   1           5       2         1
# 124     3                   1           1       2         2
#
#      fav_cuisine_coded  on_off_campus  pay_meal_out  fav_food  fruit_day  \
# 0                    3              1             2         1          5
# 1                    1              1             4         1          4
# 2                    1              2             3         3          5
# 3                    3              1             2         1          4
# 4                    1              1             4         3          4
# ..                 ...            ...           ...       ...        ...
# 120                  1              3             4         1          5
# 121                  2              1             4         1          4
# 122                  4              1             4         1          4
# 123                  1              1             3         3          5
# 124                  2              1             3         1          3
#
#      income
# 0         5
# 1         4
# 2         6
# 3         6
# 4         6
# ..      ...
# 120       4
# 121       2
# 122       2
# 123       4
# 124       5
#
# [125 rows x 11 columns]

# %%
df1 = pd.read_csv("Data/food_cleaned_data.csv")
df1=df1[["cook","diet_current_coded","eating_out","sports","exercise","fav_cuisine_coded","on_off_campus","pay_meal_out","fav_food","fruit_day","income"]]

# %%
df1.loc[[102],:]
# Out:
#      cook  diet_current_coded  eating_out  sports  exercise  \
# 102     2                   1           3       2         1
#
#      fav_cuisine_coded  on_off_campus  pay_meal_out  fav_food  fruit_day  \
# 102                  1              1             3         3          5
#
#      income
# 102       4

# %%
df1['fav_cuisine_coded'].unique()
# Out:
# array([3, 1, 6, 4, 5, 7, 2, 8, 0])

# %%
#Plotting Boxplot for cleaned data
sns.boxplot(data=df, palette="Set1").tick_params(labelsize=8.7)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#K-Means clustering on cleaned data
k = 3
kmeans = KMeans(n_clusters = k, random_state=0).fit(df)
df['Cluster']=kmeans.labels_
kmeans.cluster_centers_
# Out:
# array([[2.85714286e+00, 1.76623377e+00, 2.67532468e+00, 1.35064935e+00,
#         1.54545455e+00, 1.07792208e+00, 1.32467532e+00, 3.55844156e+00,
#         1.63636364e+00, 4.20779221e+00, 4.97402597e+00, 3.33066907e-16],
#        [2.70370370e+00, 1.70370370e+00, 2.29629630e+00, 1.33333333e+00,
#         1.74074074e+00, 4.70370370e+00, 1.22222222e+00, 3.22222222e+00,
#         1.81481481e+00, 4.40740741e+00, 5.11111111e+00, 1.00000000e+00],
#        [2.66666667e+00, 1.80952381e+00, 2.47619048e+00, 1.57142857e+00,
#         1.80952381e+00, 4.42857143e+00, 1.42857143e+00, 3.09523810e+00,
#         1.90476190e+00, 4.04761905e+00, 2.14285714e+00, 2.00000000e+00]])

# %%
df
# Out:
#      cook  diet_current_coded  eating_out  sports  exercise  \
# 0       2                   1           3       1         1
# 1       3                   2           2       1         1
# 2       1                   3           2       2         2
# 3       2                   2           2       2         3
# 4       1                   2           2       1         1
# ..    ...                 ...         ...     ...       ...
# 120     3                   2           2       1         2
# 121     3                   2           4       1         2
# 122     3                   2           3       2         2
# 123     3                   1           5       2         1
# 124     3                   1           1       2         2
#
#      fav_cuisine_coded  on_off_campus  pay_meal_out  fav_food  fruit_day  \
# 0                    3              1             2         1          5
# 1                    1              1             4         1          4
# 2                    1              2             3         3          5
# 3                    3              1             2         1          4
# 4                    1              1             4         3          4
# ..                 ...            ...           ...       ...        ...
# 120                  1              3             4         1          5
# 121                  2              1             4         1          4
# 122                  4              1             4         1          4
# 123                  1              1             3         3          5
# 124                  2              1             3         1          3
#
#      income  Cluster
# 0         5        1
# 1         4        0
# 2         6        0
# 3         6        1
# 4         6        0
# ..      ...      ...
# 120       4        0
# 121       2        2
# 122       2        2
# 123       4        0
# 124       5        0
#
# [125 rows x 12 columns]

# %%
#Plotting Boxplot for optimal K value (K=3)
fig, axes = plt.subplots(1, k, sharey=True)
axes[0].set_ylabel('Coded Values', fontsize=20)

for i in range(k):
     plt.sca(axes[i])
     plt.xticks(rotation=45,ha='right')
     sns.boxplot(palette="Set1",data = df[df['Cluster'] == i].drop('Cluster',1), ax=axes[i]).tick_params(labelsize=8.7)
        
plt.show()

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 60)
    res = kmeans.fit(df)
    print(res)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# KMeans(n_clusters=1, random_state=60)
# KMeans(n_clusters=2, random_state=60)
# KMeans(n_clusters=3, random_state=60)
# KMeans(n_clusters=4, random_state=60)
# KMeans(n_clusters=5, random_state=60)
# KMeans(n_clusters=6, random_state=60)
# KMeans(n_clusters=7, random_state=60)
# KMeans(random_state=60)
# KMeans(n_clusters=9, random_state=60)
# KMeans(n_clusters=10, random_state=60)
